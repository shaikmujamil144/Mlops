# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
df = pd.read_csv("student_placement_dataset_700.csv")

# %%
print('Value counts for Placement_Status before encoding:')
display(df['Placement_Status'].value_counts())
# Out:
# Value counts for Placement_Status before encoding:
# Placement_Status
# 0    700
# Name: count, dtype: int64

# %%
print("First 5 Records")
df.head()
# Out:
# First 5 Records
#    Student_ID  Gender  Age  Attendance_Percentage  CRT_Attendance_Percentage  \
# 0        1001    Male   20                     72                         55
# 1        1002    Male   24                     81                         54
# 2        1003  Female   20                     77                         94
# 3        1004    Male   20                     57                         82
# 4        1005    Male   22                     99                         99
#
#    Practice_Hours_Per_Week  Previous_Sem_CGPA  Internal_Marks  Verbal_Score  \
# 0                        7               6.13              46            46
# 1                       14               8.15              91            35
# 2                       11               8.22              91            40
# 3                        7               8.98              45            64
# 4                       21               8.42              78            56
#
# ...

# %%
print("Last 5 Records")
df.tail()
# Out:
# Last 5 Records
#      Student_ID  Gender  Age  Attendance_Percentage  \
# 695        1696  Female   20                     74
# 696        1697  Female   20                     66
# 697        1698    Male   20                     61
# 698        1699  Female   21                     69
# 699        1700  Female   21                     87
#
#      CRT_Attendance_Percentage  Practice_Hours_Per_Week  Previous_Sem_CGPA  \
# 695                         97                        9               7.76
# 696                         69                       13               7.18
# 697                         45                       20               5.57
# 698                         89                       14               7.98
# 699                         58                        8               9.46
#
#      Internal_Marks  Verbal_Score  Aptitude_Score  Coding_Score  \
# 695              95            50              98            88
# ...

# %%
print("Last 5 Records")
df.tail()
# Out:
# Last 5 Records
#      Student_ID  Gender  Age  Attendance_Percentage  \
# 695        1696  Female   20                     74
# 696        1697  Female   20                     66
# 697        1698    Male   20                     61
# 698        1699  Female   21                     69
# 699        1700  Female   21                     87
#
#      CRT_Attendance_Percentage  Practice_Hours_Per_Week  Previous_Sem_CGPA  \
# 695                         97                        9               7.76
# 696                         69                       13               7.18
# 697                         45                       20               5.57
# 698                         89                       14               7.98
# 699                         58                        8               9.46
#
#      Internal_Marks  Verbal_Score  Aptitude_Score  Coding_Score  \
# 695              95            50              98            88
# ...

# %%
print("Rows and Columns")
print(df.shape)
# Out:
# Rows and Columns
# (700, 19)

# %%
print(df.columns)
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Attendance_Percentage',
#        'CRT_Attendance_Percentage', 'Practice_Hours_Per_Week',
#        'Previous_Sem_CGPA', 'Internal_Marks', 'Verbal_Score', 'Aptitude_Score',
#        'Coding_Score', 'Internships_Completed', 'Certifications',
#        'Hackathons_Participated', 'Leadership_Activities',
#        'Mock_Interview_Score', 'Projects_Completed', 'Communication_Skills',
#        'Placement_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Student_ID                 700 non-null    int64
#  1   Gender                     700 non-null    object
#  2   Age                        700 non-null    int64
#  3   Attendance_Percentage      700 non-null    int64
#  4   CRT_Attendance_Percentage  700 non-null    int64
#  5   Practice_Hours_Per_Week    700 non-null    int64
#  6   Previous_Sem_CGPA          700 non-null    float64
#  7   Internal_Marks             700 non-null    int64
#  8   Verbal_Score               700 non-null    int64
#  9   Aptitude_Score             700 non-null    int64
#  10  Coding_Score               700 non-null    int64
#  11  Internships_Completed      700 non-null    int64
#  12  Certifications             700 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                   0
# Gender                       0
# Age                          0
# Attendance_Percentage        0
# CRT_Attendance_Percentage    0
# Practice_Hours_Per_Week      0
# Previous_Sem_CGPA            0
# Internal_Marks               0
# Verbal_Score                 0
# Aptitude_Score               0
# Coding_Score                 0
# Internships_Completed        0
# Certifications               0
# Hackathons_Participated      0
# Leadership_Activities        0
# Mock_Interview_Score         0
# Projects_Completed           0
# Communication_Skills         0
# Placement_Status             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Student_ID                     int64
# Gender                        object
# Age                            int64
# Attendance_Percentage          int64
# CRT_Attendance_Percentage      int64
# Practice_Hours_Per_Week        int64
# Previous_Sem_CGPA            float64
# Internal_Marks                 int64
# Verbal_Score                   int64
# Aptitude_Score                 int64
# Coding_Score                   int64
# Internships_Completed          int64
# Certifications                 int64
# Hackathons_Participated        int64
# Leadership_Activities          int64
# Mock_Interview_Score           int64
# Projects_Completed             int64
# Communication_Skills           int64
# Placement_Status              object
# dtype: object

# %%
encoder = LabelEncoder()

df["Gender"] = encoder.fit_transform(df["Gender"])

# %%
df["Placement_Status"] = encoder.fit_transform(df["Placement_Status"])
df.head()
# Out:
#    Student_ID  Gender  Age  Attendance_Percentage  CRT_Attendance_Percentage  \
# 0        1001       1   20                     72                         55
# 1        1002       1   24                     81                         54
# 2        1003       0   20                     77                         94
# 3        1004       1   20                     57                         82
# 4        1005       1   22                     99                         99
#
#    Practice_Hours_Per_Week  Previous_Sem_CGPA  Internal_Marks  Verbal_Score  \
# 0                        7               6.13              46            46
# 1                       14               8.15              91            35
# 2                       11               8.22              91            40
# 3                        7               8.98              45            64
# 4                       21               8.42              78            56
#
# ...

# %%
X = df.drop(["Student_ID", "Placement_Status"], axis=1)

y = df["Placement_Status"]
X.head()
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Placement_Status, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (560, 17)
# (560,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (140, 17)
# (140,)

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1225/180087699.py in <cell line: 0>()
# ----> 1 model.fit(X_train, y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1299         classes_ = self.classes_
#    1300         if n_classes < 2:
# -> 1301             raise ValueError(
#    1302                 "This solver needs samples of at least 2 classes"
#    1303                 " in the data, but the data contains only one"
#
# ...

# %%
y_pred = model.predict(X_test)
print(y_pred)

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy :", accuracy)

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)

# %%
print(classification_report(y_test, y_pred))

# %%
student = X.iloc[[5]]

prediction = model.predict(student)

if prediction[0] == 1:
    print("Placed")
else:
    print("Not Placed")

# %%
students = X.iloc[0:10]

predictions = model.predict(students)

print(predictions)

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_[0]
})

importance.sort_values(by="Coefficient", ascending=False)

# %%
with open("../Models/placement_model.pkl", "wb") as file:
    pickle.dump(model, file)

print("Model Saved Successfully")

# %%
with open("../Models/placement_model.pkl", "rb") as file:
    loaded_model = pickle.load(file)

print("Model Loaded Successfully")

# %%
prediction = loaded_model.predict(student)

if prediction[0] == 1:
    print("Placed")
else:
    print("Not Placed")

# %%
print("="*60)
print("Student Placement Prediction System")
print("Version 1 Completed Successfully")
print("="*60)
